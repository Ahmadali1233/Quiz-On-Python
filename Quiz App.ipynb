# %%
#  Math Quiz
import tkinter as tk
from tkinter import *
import tkinter.font as font
#create instance
win=Tk()
# Changing title
win.title("Math Quiz")
#font
myFont = font.Font(family="Trajan", size =  "25", weight="bold")
#window color
win.configure(bg="light green")
#add label method 2
#question 1



mylabel = tk.Label(win, text="What is 33 + 47=", bg="light green")
mylabel.grid(column= 0, row=0)
mylabel['font'] = myFont
# button function
def click_me():
    btn3.configure(text="Correct")
    btn3.configure(bg="#0052cc", fg="#ffffff")
    mylabel.configure(foreground="blue")
    mylabel.configure(text="80")
def click_me2():
    btn.configure(text="Wrong")
    btn.configure(bg="#0052cc", fg="#ffffff")
    mylabel.configure(foreground="red")
    mylabel.configure(text="100")
def click_me3():
    btn2.configure(text="Wrong")
    btn2.configure(bg="#0052cc", fg="#ffffff")
    mylabel.configure(foreground="red")
    mylabel.configure(text="93")    
def click_me4():
    btn4.configure(text="Wrong")
    btn4.configure(bg="#0052cc", fg="#ffffff")
    mylabel.configure(foreground="red")
    mylabel.configure(text="81") 
# Adding a button
btn= tk.Button(win,text="   100   ", command=click_me2, bg="#0052cc", fg="#ffffff")
btn.grid(column= 0, row=1)
btn['font'] = myFont

btn2= tk.Button(win,text="   93   ", command=click_me3, bg="#0052cc", fg="#ffffff")
btn2.grid(column= 0, row=2)
btn2['font'] = myFont

btn3= tk.Button(win,text="   80   ", command=click_me, bg="#0052cc", fg="#ffffff")
btn3.grid(column= 0, row=3)
btn3['font'] = myFont

btn4= tk.Button(win,text="   81   ", command=click_me4, bg="#0052cc", fg="#ffffff")
btn4.grid(column= 0, row=4)
btn4['font'] = myFont

#question 2

mylabel2 = tk.Label(win, text="What is 43 + 62=", bg="light green")
mylabel2.grid(column= 0, row=6)
mylabel2['font'] = myFont
# button function
def click_me01():
    btn02.configure(text="Correct")
    btn02.configure(bg="#0052cc", fg="#ffffff")
    mylabel2.configure(foreground="blue")
    mylabel2.configure(text="105")
def click_me02():
    btn03.configure(text="Wrong")
    btn03.configure(bg="#0052cc", fg="#ffffff")
    mylabel2.configure(foreground="red")
    mylabel2.configure(text="104")
def click_me03():
    btn04.configure(text="Wrong")
    btn04.configure(bg="#0052cc", fg="#ffffff")
    mylabel2.configure(foreground="red")
    mylabel2.configure(text="106")    
def click_me04():
    btn01.configure(text="Wrong")
    btn01.configure(bg="#0052cc", fg="#ffffff")
    mylabel2.configure(foreground="red")
    mylabel2.configure(text="19") 
# Adding a button
btn01= tk.Button(win,text="   19   ", command=click_me04, bg="#0052cc", fg="#ffffff")
btn01.grid(column= 0, row=7)
btn01['font'] = myFont

btn02= tk.Button(win,text="   105   ", command=click_me01, bg="#0052cc", fg="#ffffff")
btn02.grid(column= 0, row=8)
btn02['font'] = myFont

btn03= tk.Button(win,text="   104   ", command=click_me02, bg="#0052cc", fg="#ffffff")
btn03.grid(column= 0, row=9)
btn03['font'] = myFont

btn04= tk.Button(win,text="   106   ", command=click_me03, bg="#0052cc", fg="#ffffff")
btn04.grid(column= 0, row=10)
btn04['font'] = myFont

#question 3

mylabel3 = tk.Label(win, text="What is 45 + 72=", bg="light green")
mylabel3.grid(column= 60, row=0, padx=50, pady=20)
mylabel3['font'] = myFont
# button function
def click_me001():
    btn004.configure(text="Correct")
    btn004.configure(bg="#0052cc", fg="#ffffff")
    mylabel3.configure(foreground="blue")
    mylabel3.configure(text="117")
def click_me002():
    btn002.configure(text="Wrong")
    btn002.configure(bg="#0052cc", fg="#ffffff")
    mylabel3.configure(foreground="red")
    mylabel3.configure(text="116")
def click_me003():
    btn003.configure(text="Wrong")
    btn003.configure(bg="#0052cc", fg="#ffffff")
    mylabel3.configure(foreground="red")
    mylabel3.configure(text="156")    
def click_me004():
    btn001.configure(text="Wrong")
    btn001.configure(bg="#0052cc", fg="#ffffff")
    mylabel3.configure(foreground="red")
    mylabel3.configure(text="134") 
# Adding a button
btn001= tk.Button(win,text="   134   ", command=click_me004, bg="#0052cc", fg="#ffffff")
btn001.grid(column= 60, row=1)
btn001['font'] = myFont

btn002= tk.Button(win,text="   116   ", command=click_me002, bg="#0052cc", fg="#ffffff")
btn002.grid(column= 60, row=2)
btn002['font'] = myFont

btn003= tk.Button(win,text="   156   ", command=click_me003, bg="#0052cc", fg="#ffffff")
btn003.grid(column= 60, row=3)
btn003['font'] = myFont

btn004= tk.Button(win,text="   117   ", command=click_me001, bg="#0052cc", fg="#ffffff")
btn004.grid(column= 60, row=4)
btn004['font'] = myFont

#question 4

mylabel4 = tk.Label(win, text="What is 44 + 27=", bg="light green")
mylabel4.grid(column= 60, row=6)
mylabel4['font'] = myFont
# button function
def click_me0001():
    btn0004.configure(text="Correct")
    btn0004.configure(bg="#0052cc", fg="#ffffff")
    mylabel4.configure(foreground="blue")
    mylabel4.configure(text="71")
def click_me0002():
    btn0002.configure(text="Wrong")
    btn0002.configure(bg="#0052cc", fg="#ffffff")
    mylabel4.configure(foreground="red")
    mylabel4.configure(text="72")
def click_me0003():
    btn0003.configure(text="Wrong")
    btn0003.configure(bg="#0052cc", fg="#ffffff")
    mylabel4.configure(foreground="red")
    mylabel4.configure(text="70")    
def click_me0004():
    btn0001.configure(text="Wrong")
    btn0001.configure(bg="#0052cc", fg="#ffffff")
    mylabel5.configure(foreground="red")
    mylabel5.configure(text="17") 
# Adding a button
btn0001= tk.Button(win,text="   17   ", command=click_me0004, bg="#0052cc", fg="#ffffff")
btn0001.grid(column= 60, row=7)
btn0001['font'] = myFont

btn0002= tk.Button(win,text="   72   ", command=click_me0002, bg="#0052cc", fg="#ffffff")
btn0002.grid(column= 60, row=8)
btn0002['font'] = myFont

btn0003= tk.Button(win,text="   70   ", command=click_me0003, bg="#0052cc", fg="#ffffff")
btn0003.grid(column= 60, row=9)
btn0003['font'] = myFont

btn0004= tk.Button(win,text="   71   ", command=click_me0001, bg="#0052cc", fg="#ffffff")
btn0004.grid(column= 60, row=10)
btn0004['font'] = myFont


#question 5

mylabel5 = tk.Label(win, text="What is 37 + 66=", bg="light green")
mylabel5.grid(column= 120, row=0)
mylabel5['font'] = myFont
# button function
def click_me00001():
    btn00002.configure(text="Correct")
    btn00002.configure(bg="#0052cc", fg="#ffffff")
    mylabel5.configure(foreground="blue")
    mylabel5.configure(text="103")
def click_me00002():
    btn00004.configure(text="Wrong")
    btn00004.configure(bg="#0052cc", fg="#ffffff")
    mylabel5.configure(foreground="red")
    mylabel5.configure(text="102")
def click_me00003():
    btn00001.configure(text="Wrong")
    btn00001.configure(bg="#0052cc", fg="#ffffff")
    mylabel5.configure(foreground="red")
    mylabel5.configure(text="104")    
def click_me00004():
    btn00003.configure(text="Wrong")
    btn00003.configure(bg="#0052cc", fg="#ffffff")
    mylabel5.configure(foreground="red")
    mylabel5.configure(text="100") 
# Adding a button
btn00001= tk.Button(win,text="   104   ", command=click_me00003, bg="#0052cc", fg="#ffffff")
btn00001.grid(column= 120, row=1)
btn00001['font'] = myFont

btn00002= tk.Button(win,text="   103   ", command=click_me00001, bg="#0052cc", fg="#ffffff")
btn00002.grid(column= 120, row=2)
btn00002['font'] = myFont



btn00003= tk.Button(win,text="   100  ", command=click_me00004, bg="#0052cc", fg="#ffffff")
btn00003.grid(column= 120, row=3)
btn00003['font'] = myFont

btn00004= tk.Button(win,text="   102   ", command=click_me00002, bg="#0052cc", fg="#ffffff")
btn00004.grid(column= 120, row=4)
btn00004['font'] = myFont


#question 6

mylabel6 = tk.Label(win, text="What is 42 + 64=", bg="light green")
mylabel6.grid(column= 120, row=6)
mylabel6['font'] = myFont
# button function
def click_me000001():
    btn000002.configure(text="Correct")
    btn000002.configure(bg="#0052cc", fg="#ffffff")
    mylabel6.configure(foreground="blue")
    mylabel6.configure(text="106")
def click_me000002():
    btn000001.configure(text="Wrong")
    btn000001.configure(bg="#0052cc", fg="#ffffff")
    mylabel6.configure(foreground="red")
    mylabel6.configure(text="10")
def click_me000003():
    btn000004.configure(text="Wrong")
    btn000004.configure(bg="#0052cc", fg="#ffffff")
    mylabel6.configure(foreground="red")
    mylabel6.configure(text="22")    
def click_me000004():
    btn000003.configure(text="Wrong")
    btn000003.configure(bg="#0052cc", fg="#ffffff")
    mylabel6.configure(foreground="red")
    mylabel6.configure(text="105") 
# Adding a button
btn000001= tk.Button(win,text="   10   ", command=click_me000002, bg="#0052cc", fg="#ffffff")
btn000001.grid(column= 120, row=7)
btn000001['font'] = myFont

btn000002= tk.Button(win,text="   106   ", command=click_me000001, bg="#0052cc", fg="#ffffff")
btn000002.grid(column= 120, row=8)
btn000002['font'] = myFont



btn000003= tk.Button(win,text="   105  ", command=click_me000004, bg="#0052cc", fg="#ffffff")
btn000003.grid(column= 120, row=9)
btn000003['font'] = myFont

btn000004= tk.Button(win,text="   22   ", command=click_me000003, bg="#0052cc", fg="#ffffff")
btn000004.grid(column= 120, row=10)
btn000004['font'] = myFont

#question 7

mylabel7 = tk.Label(win, text="What is 33 + 92=", bg="light green", padx=30)
mylabel7.grid(column= 160, row=0)
mylabel7['font'] = myFont
# button function
def click_me0000001():
    btn0000002.configure(text="Correct")
    btn0000002.configure(bg="#0052cc", fg="#ffffff")
    mylabel7.configure(foreground="blue")
    mylabel7.configure(text="125")
def click_me0000002():
    btn0000004.configure(text="Wrong")
    btn0000004.configure(bg="#0052cc", fg="#ffffff")
    mylabel7.configure(foreground="red")
    mylabel7.configure(text="100")
def click_me0000003():
    btn0000001.configure(text="Wrong")
    btn0000001.configure(bg="#0052cc", fg="#ffffff")
    mylabel7.configure(foreground="red")
    mylabel7.configure(text="120")    
def click_me0000004():
    btn0000003.configure(text="Wrong")
    btn0000003.configure(bg="#0052cc", fg="#ffffff")
    mylabel7.configure(foreground="red")
    mylabel7.configure(text="115") 
# Adding a button
btn0000001= tk.Button(win,text="   120   ", command=click_me0000003, bg="#0052cc", fg="#ffffff")
btn0000001.grid(column= 160, row=1)
btn0000001['font'] = myFont

btn0000002= tk.Button(win,text="   125   ", command=click_me0000001, bg="#0052cc", fg="#ffffff")
btn0000002.grid(column= 160, row=2)
btn0000002['font'] = myFont



btn0000003= tk.Button(win,text="   105  ", command=click_me0000004, bg="#0052cc", fg="#ffffff")
btn0000003.grid(column= 160, row=3)
btn0000003['font'] = myFont

btn0000004= tk.Button(win,text="   22   ", command=click_me0000002, bg="#0052cc", fg="#ffffff")
btn0000004.grid(column= 160, row=4)
btn0000004['font'] = myFont
#question 8

mylabel8 = tk.Label(win, text="What is 65 + 37=", bg="light green", padx=30)
mylabel8.grid(column= 160, row=6)
mylabel8['font'] = myFont
# button function
def click_me00000001():
    btn00000003.configure(text="Correct")
    btn00000003.configure(bg="#0052cc", fg="#ffffff")
    mylabel8.configure(foreground="blue")
    mylabel8.configure(text="102")
def click_me00000002():
    btn00000001.configure(text="Wrong")
    btn00000001.configure(bg="#0052cc", fg="#ffffff")
    mylabel8.configure(foreground="red")
    mylabel8.configure(text="100")
def click_me00000003():
    btn00000004.configure(text="Wrong")
    btn00000004.configure(bg="#0052cc", fg="#ffffff")
    mylabel8.configure(foreground="red")
    mylabel8.configure(text="121")    
def click_me00000004():
    btn00000002.configure(text="Wrong")
    btn00000002.configure(bg="#0052cc", fg="#ffffff")
    mylabel8.configure(foreground="red")
    mylabel8.configure(text="105") 
# Adding a button
btn00000001= tk.Button(win,text="   100   ", command=click_me00000002, bg="#0052cc", fg="#ffffff")
btn00000001.grid(column= 160, row=7)
btn00000001['font'] = myFont

btn00000002= tk.Button(win,text="   105   ", command=click_me00000004, bg="#0052cc", fg="#ffffff")
btn00000002.grid(column= 160, row=8)
btn00000002['font'] = myFont


btn00000003= tk.Button(win,text="   102  ", command=click_me00000001, bg="#0052cc", fg="#ffffff")
btn00000003.grid(column= 160, row=9)
btn00000003['font'] = myFont

btn00000004= tk.Button(win,text="   121   ", command=click_me00000003, bg="#0052cc", fg="#ffffff")
btn00000004.grid(column= 160, row=10)
btn00000004['font'] = myFont

win.mainloop()
